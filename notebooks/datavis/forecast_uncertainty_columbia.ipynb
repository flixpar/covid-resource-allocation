# %% [markdown]
# # Distribution of Unccertainty for Columbia Forecast
# The goal of this notebook is to examine the empirical distribution of the uncertainty set for the Columbia admitted patients forecast.

# %%
using CSV, DataFrames
using Gadfly
using Statistics
using Distributions
using Loess
using LsqFit

# %%
col_dict = Dict(
    "hosp_new_1" => 1,
    "hosp_new_2point5" => 2.5,
    "hosp_new_5" => 5,
    "hosp_new_10" => 10,
    "hosp_new_15" => 15,
    "hosp_new_20" => 20,
    "hosp_new_25" => 25,
    "hosp_new_30" => 30,
    "hosp_new_35" => 35,
    "hosp_new_40" => 40,
    "hosp_new_45" => 45,
    "hosp_new_50" => 50,
    "hosp_new_55" => 55,
    "hosp_new_60" => 60,
    "hosp_new_65" => 65,
    "hosp_new_70" => 70,
    "hosp_new_75" => 75,
    "hosp_new_80" => 80,
    "hosp_new_85" => 85,
    "hosp_new_90" => 90,
    "hosp_new_95" => 95,
    "hosp_new_97point5" => 97.5,
    "hosp_new_99" => 99,
);
col_names = sort(collect(keys(col_dict)), by=k->col_dict[k])
col_vals = sort(collect(values(col_dict)));
val_to_col = Dict(v => i for (i,v) in enumerate(col_vals));
p_vals = col_vals ./ 100;

# %%
forecast = CSV.read("../../data/forecasts/columbia/2020-05-31/state_cdchosp_80contactw5p.csv")
rename!(forecast, map(x -> strip(string(x)), names(forecast)))
forecast_data = Matrix(forecast[:,col_names]);

# %% [markdown]
# ## Averaged Distribution over all States, Days

# %%
fc1 = forecast_data .- forecast_data[:,val_to_col[50]]
fc2 = max.(abs.(fc1[:,val_to_col[1]]), abs.(fc1[:,val_to_col[99]]))
fc3 = max.(1, fc2)
fc4 = fc1 ./ fc3
fc5 = mean(fc4, dims=1)[:]
fc7 = (p_vals[2:end] - p_vals[1:end-1]) ./ (fc5[2:end] - fc5[1:end-1])
fc8 = fc7 / sum(fc7);

# %%
Gadfly.plot(
    y=p_vals, x=fc5,
    Geom.point, Geom.line,
    Scale.x_continuous(minvalue=-1, maxvalue=1),
    Guide.title("CDF for Mean Normalized Admitted Patients"),
    Guide.ylabel("Cummulative Probability"),
    Guide.xlabel("Normalized Admitted Patients"),
) |> SVG()
# Out:
# SVG(141.4213562373095mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=15730, maxsize=Inf, ptr=15731, mark=-1), nothing, "img-85bb36ed", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.FontSizePrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing,Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokeDashPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(18.63166666666666mm, 10.611666666666665mm), (136.4213562373095mm, 10.611666666666665mm), (136.4213562373095mm, 80.71499999999999mm), (18.63166666666666mm, 80.71499999999999mm)]) => "img-85bb36ed-4"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-85bb36ed-100", false, 100, Set(AbstractString["/Users/flixpar/.julia/packages/Gadfly/cqMtH/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-85bb36ed-5\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((18.63166666666666mm, 10.611666666666665mm), (117.78968957064285mm, 70.10333333333332mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.0351525697547204, 1.0302556603297868, 2.0703051395094407, -1.0605113206595733, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
plt = Gadfly.plot(
    x=fc5[2:end], y=fc8, ymax=fc8, ymin=fill(0.0, length(fc8)),
    Geom.ribbon, Geom.line,
    Scale.x_continuous(minvalue=-1, maxvalue=1),
    Guide.title("PDF for Mean Normalized Admitted Patients"),
    Guide.ylabel("Density"),
    Guide.xlabel("Normalized Admitted Patients"),
) |> SVG()
# Out:
# SVG(141.4213562373095mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=7771, maxsize=Inf, ptr=7772, mark=-1), nothing, "img-adca7aef", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.FontSizePrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing,Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokeDashPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(20.304999999999993mm, 10.611666666666665mm), (136.4213562373095mm, 10.611666666666665mm), (136.4213562373095mm, 80.715mm), (20.304999999999993mm, 80.715mm)]) => "img-adca7aef-4"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-adca7aef-35", false, 35, Set(AbstractString["/Users/flixpar/.julia/packages/Gadfly/cqMtH/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-adca7aef-5\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((20.304999999999993mm, 10.611666666666665mm), (116.11635623730952mm, 70.10333333333334mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.0356772208288099, 0.08242045282638294, 2.0713544416576197, -0.08484090565276586, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %% [markdown]
# ## Distribution for Example (State, Day) Pair

# %%
state = "New York"
date = "05/31/2020"
idx = findfirst(row -> row.location == state && row.Date == date, eachrow(forecast));

# %%
model = loess(Float64.(forecast_data[idx,:]), p_vals)
vs = predict(model, collect(300.0:360.0))
df_fit = DataFrame(x=collect(300.0:360.0), y=vs, method="Smoothed")
df_real = DataFrame(y=p_vals, x=forecast_data[idx,:], method="Original")
df = vcat(df_real, df_fit)
plt = Gadfly.plot(
    df, x=:x, y=:y, color=:method,
    Scale.color_discrete, Geom.point, Geom.line,
    Guide.title("CDF for Admitted Patients"),
    Guide.ylabel("Cummulative Probability"),
    Guide.xlabel("Admitted Patients"),
)
plt |> SVG()
# Out:
# SVG(141.4213562373095mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=40696, maxsize=Inf, ptr=40697, mark=-1), nothing, "img-b435c145", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.FontSizePrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing,Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokeDashPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(18.63166666666666mm, 10.611666666666665mm), (120.33468957064284mm, 10.611666666666665mm), (120.33468957064284mm, 80.71499999999999mm), (18.63166666666666mm, 80.71499999999999mm)]) => "img-b435c145-13"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-b435c145-296", false, 296, Set(AbstractString["/Users/flixpar/.julia/packages/Gadfly/cqMtH/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-b435c145-4\")\n   .drag(function() {}, function() {}, function() {});", "fig.select(\"#img-b435c145-6\")\n   .data(\"color_class\", \"color_Original\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-b435c145-7\")\n   .data(\"color_class\", \"color_Smoothed\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-b435c145-9\")\n   .data(\"color_class\", \"color_Original\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-b435c145-10\")\n   .data(\"color_class\", \"color_Smoothed\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-b435c145-14\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((18.63166666666666mm, 10.611666666666665mm), (101.70302290397618mm, 70.10333333333332mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(288.3623843434481, 1.0302556603297868, 83.27523131310379, -1.0605113206595733, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
d0 = forecast_data[idx,:]
d1 = (p_vals[2:end] - p_vals[1:end-1]) ./ (d0[2:end] - d0[1:end-1])
d2 = [0; deepcopy(d1); 0;]
for (i,v) in enumerate(d2)
    if v == Inf
        for j in i:length(d2)
            if d2[j] != Inf
                d2[i] = (d2[i-1] + d2[j]) / 2
                break
            end
        end
    end
end
d2 = d2[2:end-1]
plt1 = Gadfly.plot(
    x=d0[2:end], y=d2,
    Geom.line,
    Guide.title("PDF for Admitted Patients - Unsmoothed"),
    Guide.ylabel("Density"),
    Guide.xlabel("Admitted Patients"),
    Coord.cartesian(ymin=0.0, ymax=0.06),
)

z = Float64.(forecast_data[idx,:])
model = loess(z, p_vals)
lb, ub = floor(minimum(z)), ceil(maximum(z))
d0 = collect(lb:1.0:ub)
d1 = predict(model, d0)
q = (d1[2:end] - d1[1:end-1]) ./ (d0[2:end] - d0[1:end-1])
plt2 = Gadfly.plot(
    x=d0[2:end], y=q,
    Geom.line,
    Guide.title("PDF for Admitted Patients - Smoothed"),
    Guide.ylabel("Density"),
    Guide.xlabel("Admitted Patients"),
    Coord.cartesian(ymin=0.0, ymax=0.06),
)

plt = hstack(plt1, plt2)
plt |> SVG(24cm, 10cm)
# Out:
# SVG(240.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=17787, maxsize=Inf, ptr=17788, mark=-1), nothing, "img-e5697b70", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.StrokeDashPrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.FontSizePrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(140.305mm, 10.611666666666665mm), (235.0mm, 10.611666666666665mm), (235.0mm, 80.715mm), (140.305mm, 80.715mm)]) => "img-e5697b70-4",Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(20.304999999999993mm, 10.611666666666665mm), (115.0mm, 10.611666666666665mm), (115.0mm, 80.715mm), (20.304999999999993mm, 80.715mm)]) => "img-e5697b70-55"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-e5697b70-92", false, 92, Set(AbstractString["/Users/flixpar/.julia/packages/Gadfly/cqMtH/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-e5697b70-5\")\n   .init_gadfly();", "fig.select(\"#img-e5697b70-56\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((20.304999999999993mm, 10.611666666666665mm), (94.69500000000001mm, 70.10333333333334mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(288.2358454159546, 0.0618153396197872, 83.52830916809084, -0.0636306792395744, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
μ = forecast_data[idx,val_to_col[50]]
σ = forecast_data[idx,val_to_col[85]] - μ

@show (μ, σ)

dist = Normal(μ, σ)

xvals = collect(floor(μ-4σ):1:ceil(μ+4σ))
yvals = Float32.(pdf.(dist, xvals))

plt = Gadfly.plot(
    x=xvals, y=yvals, ymin=fill(0.0, length(yvals)), ymax=yvals,
    Geom.line, Geom.ribbon,
    Guide.ylabel("Density"), Guide.xlabel("Admitted Patients"),
    Guide.title("Normal Distribution using MLE"),
)
plt |> SVG()
# Out:
# (μ, σ) = (327, 17)
# SVG(141.4213562373095mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=11804, maxsize=Inf, ptr=11805, mark=-1), nothing, "img-d17d5b56", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.FontSizePrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing,Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokeDashPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(21.978333333333353mm, 10.611666666666665mm), (136.42135623730954mm, 10.611666666666665mm), (136.42135623730954mm, 80.715mm), (21.978333333333353mm, 80.715mm)]) => "img-d17d5b56-4"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-d17d5b56-36", false, 36, Set(AbstractString["/Users/flixpar/.julia/packages/Gadfly/cqMtH/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-d17d5b56-5\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((21.978333333333353mm, 10.611666666666665mm), (114.44302290397619mm, 70.10333333333334mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(247.28366725111434, 0.02575639150824467, 155.43266549777132, -0.026512783016489336, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
model = loess(Float64.(forecast_data[idx,:]), p_vals)
vs = predict(model, collect(300.0:360.0))

df_real = DataFrame(y=p_vals, x=forecast_data[idx,:], Method="Original")
df_fit = DataFrame(x=collect(300.0:360.0), y=cdf.(dist, collect(300.0:360.0)), Method="Fit Normal")
df = vcat(df_real, df_fit)

plt_point = Gadfly.plot(
    df, x=:x, y=:y, color=:Method,
    Geom.point, Geom.line, Scale.color_discrete,
    Guide.title("CDF for Admitted Patients"),
    Guide.ylabel("Cummulative Probability"),
    Guide.xlabel("Admitted Patients"),
)
plt_line = Gadfly.plot(
    df, x=:x, y=:y, color=:Method,
    Scale.color_discrete, Geom.line,
    Guide.title("CDF for Admitted Patients"),
    Guide.ylabel("Cummulative Probability"),
    Guide.xlabel("Admitted Patients"),
)

plt = hstack(plt_point, plt_line)
plt |> SVG(24cm, 10cm)
# Out:
# SVG(240.0mm, 100.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=50292, maxsize=Inf, ptr=50293, mark=-1), nothing, "img-5ab817ea", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Compose.Property}}(Compose.Property{Compose.StrokePrimitive} => nothing,Compose.Property{Compose.LineWidthPrimitive} => nothing,Compose.Property{Compose.JSIncludePrimitive} => nothing,Compose.Property{Compose.FillPrimitive} => nothing,Compose.Property{Compose.SVGClassPrimitive} => nothing,Compose.Property{Compose.FontSizePrimitive} => nothing,Compose.Property{Compose.SVGAttributePrimitive} => nothing,Compose.Property{Compose.JSCallPrimitive} => nothing,Compose.Property{Compose.FontPrimitive} => nothing,Compose.Property{Compose.StrokeDashPrimitive} => nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(138.63166666666666mm, 10.611666666666665mm), (218.36666666666667mm, 10.611666666666665mm), (218.36666666666667mm, 80.71499999999999mm), (138.63166666666666mm, 80.71499999999999mm)]) => "img-5ab817ea-13",Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(18.63166666666666mm, 10.611666666666665mm), (98.36666666666666mm, 10.611666666666665mm), (98.36666666666666mm, 80.71499999999999mm), (18.63166666666666mm, 80.71499999999999mm)]) => "img-5ab817ea-65"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-5ab817ea-348", false, 348, Set(AbstractString["/Users/flixpar/.julia/packages/Gadfly/cqMtH/src/gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-5ab817ea-4\")\n   .drag(function() {}, function() {}, function() {});", "fig.select(\"#img-5ab817ea-6\")\n   .data(\"color_class\", \"color_Original\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ab817ea-7\")\n   .data(\"color_class\", \"color_Fit_Normal\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ab817ea-9\")\n   .data(\"color_class\", \"color_Original\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ab817ea-10\")\n   .data(\"color_class\", \"color_Fit_Normal\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ab817ea-14\")\n   .init_gadfly();", "fig.select(\"#img-5ab817ea-56\")\n   .drag(function() {}, function() {}, function() {});", "fig.select(\"#img-5ab817ea-58\")\n   .data(\"color_class\", \"color_Original\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ab817ea-59\")\n   .data(\"color_class\", \"color_Fit_Normal\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ab817ea-61\")\n   .data(\"color_class\", \"color_Original\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ab817ea-62\")\n   .data(\"color_class\", \"color_Fit_Normal\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ab817ea-66\")\n   .init_gadfly();"], false, :none, (Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((18.63166666666666mm, 10.611666666666665mm), (79.735mm, 70.10333333333332mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(287.88737043639003, 1.0302556603297868, 84.22525912721991, -1.0605113206595733, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))
